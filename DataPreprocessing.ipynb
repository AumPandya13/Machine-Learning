# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
headers_data = ["symboling","normalized-losses","make","fuel-type","aspiration", "num-of-doors","body-style",
         "drive-wheels","engine-location","wheel-base", "length","width","height","curb-weight","engine-type",
         "num-of-cylinders", "engine-size","fuel-system","bore","stroke","compression-ratio","horsepower",
         "peak-rpm","city-mpg","highway-mpg","price"]
print("headers\n", type(headers_data))
# Out:
# headers
#  <class 'list'>

# %%
file_path = "C:/Users/aumpa/Documents/ML/batwebs/bowling.csv"
df = pd.read_csv(file_path, names=headers_data)
df.head()
# Out:
#   symboling normalized-losses  make            fuel-type aspiration  \
# 0   MatchID         InningsNo  Team           PlayerName      Overs
# 1         1                 1   KKR          Umesh Yadav        4.0
# 2         1                 1   KKR          Shivam Mavi        4.0
# 3         1                 1   KKR  Varun Chakaravarthy        4.0
# 4         1                 1   KKR         Sunil Narine        4.0
#
#   num-of-doors body-style drive-wheels engine-location wheel-base  ...  \
# 0      Maidens       Runs      Wickets           Wides    NoBalls  ...
# 1            0         20            2               2          1  ...
# 2            0         35            0               1          1  ...
# 3            0         23            1               1          0  ...
# 4            0         15            0               0          0  ...
#
#   engine-size fuel-system   bore      stroke compression-ratio horsepower  \
# ...

# %%
df.dtypes
# Out:
# symboling             object
# normalized-losses     object
# make                  object
# fuel-type             object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base            object
# length                object
# width                 object
# height                object
# curb-weight           object
# engine-type           object
# num-of-cylinders      object
# engine-size           object
# fuel-system           object
# bore                  object
# stroke                object
# compression-ratio    float64
# horsepower           float64
# peak-rpm             float64
# city-mpg             float64
# highway-mpg          float64
# price                float64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 858 entries, 0 to 857
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          858 non-null    object
#  1   normalized-losses  858 non-null    object
#  2   make               858 non-null    object
#  3   fuel-type          858 non-null    object
#  4   aspiration         858 non-null    object
#  5   num-of-doors       858 non-null    object
#  6   body-style         858 non-null    object
#  7   drive-wheels       858 non-null    object
#  8   engine-location    858 non-null    object
#  9   wheel-base         858 non-null    object
#  10  length             858 non-null    object
#  11  width              858 non-null    object
#  12  height             858 non-null    object
#  13  curb-weight        858 non-null    object
#  14  engine-type        858 non-null    object
#  15  num-of-cylinders   858 non-null    object
# ...

# %%
df.replace("?", np.nan, inplace = True)
df.head()
# Out:
#   symboling normalized-losses  make            fuel-type aspiration  \
# 0   MatchID         InningsNo  Team           PlayerName      Overs
# 1         1                 1   KKR          Umesh Yadav        4.0
# 2         1                 1   KKR          Shivam Mavi        4.0
# 3         1                 1   KKR  Varun Chakaravarthy        4.0
# 4         1                 1   KKR         Sunil Narine        4.0
#
#   num-of-doors body-style drive-wheels engine-location wheel-base  ...  \
# 0      Maidens       Runs      Wickets           Wides    NoBalls  ...
# 1            0         20            2               2          1  ...
# 2            0         35            0               1          1  ...
# 3            0         23            1               1          0  ...
# 4            0         15            0               0          0  ...
#
#   engine-size fuel-system   bore      stroke compression-ratio horsepower  \
# ...

# %%
missing_data = df.isnull()
missing_data
# Out:
#      symboling  normalized-losses   make  fuel-type  aspiration  num-of-doors  \
# 0        False              False  False      False       False         False
# 1        False              False  False      False       False         False
# 2        False              False  False      False       False         False
# 3        False              False  False      False       False         False
# 4        False              False  False      False       False         False
# ..         ...                ...    ...        ...         ...           ...
# 853      False              False  False      False       False         False
# 854      False              False  False      False       False         False
# 855      False              False  False      False       False         False
# 856      False              False  False      False       False         False
# 857      False              False  False      False       False         False
#
# ...

# %%
for column in headers_data:
  print(column)
  print(missing_data[column].value_counts())
  print(" ")
# Out:
# symboling
# symboling
# False    858
# Name: count, dtype: int64
#
# normalized-losses
# normalized-losses
# False    858
# Name: count, dtype: int64
#
# make
# make
# False    858
# Name: count, dtype: int64
#
# fuel-type
# fuel-type
# False    858
# Name: count, dtype: int64
#
# aspiration
# aspiration
# False    858
# Name: count, dtype: int64
#
# num-of-doors
# num-of-doors
# False    858
# Name: count, dtype: int64
#
# body-style
# body-style
# False    858
# Name: count, dtype: int64
#
# drive-wheels
# drive-wheels
# False    858
# Name: count, dtype: int64
#
# engine-location
# engine-location
# False    858
# Name: count, dtype: int64
#
# wheel-base
# wheel-base
# False    858
# Name: count, dtype: int64
#
# length
# length
# False    858
# Name: count, dtype: int64
#
# width
# width
# False    858
# Name: count, dtype: int64
#
# height
# height
# False    858
# Name: count, dtype: int64
#
# curb-weight
# curb-weight
# False    858
# Name: count, dtype: int64
#
# engine-type
# ...

# %%
# Handling missing values: Imputation or removal
# Example: Impute missing numeric values with mean, and categorical values with mode
numeric_cols = df.select_dtypes(include=np.number).columns.tolist()
categorical_cols = df.select_dtypes(exclude=np.number).columns.tolist()

# %%
# Impute missing numeric values with mean
for col in numeric_cols:
    df[col] = df[col].astype(float)
    df[col].fillna(df[col].mean(), inplace=True)

# %%
# Impute missing categorical values with mode
for col in categorical_cols:
    df[col].fillna(df[col].mode()[0], inplace=True)

# %%
# Convert numeric columns to appropriate data types if needed
numeric_cols_except_price = [col for col in numeric_cols if col != 'price']
df[numeric_cols_except_price] = df[numeric_cols_except_price].astype(float)

# %%
print("\nPreprocessed DataFrame:\n", df.head())
# Out:
# Preprocessed DataFrame:
#    symboling normalized-losses  make            fuel-type aspiration  \
# 0   MatchID         InningsNo  Team           PlayerName      Overs
# 1         1                 1   KKR          Umesh Yadav        4.0
# 2         1                 1   KKR          Shivam Mavi        4.0
# 3         1                 1   KKR  Varun Chakaravarthy        4.0
# 4         1                 1   KKR         Sunil Narine        4.0
#
#   num-of-doors body-style drive-wheels engine-location wheel-base  ...  \
# 0      Maidens       Runs      Wickets           Wides    NoBalls  ...
# 1            0         20            2               2          1  ...
# 2            0         35            0               1          1  ...
# 3            0         23            1               1          0  ...
# 4            0         15            0               0          0  ...
#
#   engine-size fuel-system   bore      stroke compression-ratio horsepower  \
# ...
