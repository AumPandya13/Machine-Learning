# %% [markdown]
# # **Session 2**

# %%
import pandas as pd #importing library

# %% [markdown]
# ## HOW TO READ FILE

# %% [markdown]
# You need to import it into your Python script or Jupyter Notebook. To read data from a file (e.g., CSV, Excel, etc.), you can use the read_csv() function.

# %%
bat_df = pd.read_csv('batting.csv') #reading csv file

# %%
#reading head of the data
bat_df.head()
# Out:
#    MatchID  InningsNo Team        PlayerName  MatchPlayingOrder  \
# 0        1          1  CSK  Ruturaj  Gaikwad                  1
# 1        1          1  CSK      Devon Conway                  2
# 2        1          1  CSK     Robin Uthappa                  3
# 3        1          1  CSK     Ambati Rayudu                  4
# 4        1          1  CSK   Ravindra Jadeja                  5
#
#             BowlerName                                   OutDesc  Runs  Balls  \
# 0          Umesh Yadav               c Nitish Rana b Umesh Yadav     0      4
# 1          Umesh Yadav              c Shreyas Iyer b Umesh Yadav     3      8
# 2  Varun Chakaravarthy  st Sheldon Jackson b Varun Chakaravarthy    28     21
# 3         Sunil Narine                    run out (Shreyas Iyer)    15     17
# 4                  NaN                                   not out    26     28
#
#    DotBalls  Ones  Twos  Threes  Fours  Sixes StrikeRate  WicketNo  \
# ...

# %% [markdown]
# ###  Reading tail of the data

# %%
bat_df.tail()
# Out:
#       MatchID  InningsNo Team       PlayerName  MatchPlayingOrder BowlerName  \
# 1623       76          2   GT      Rashid Khan                  7        NaN
# 1624       76          2   GT      Sai Kishore                  8        NaN
# 1625       76          2   GT   Mohammad Shami                  9        NaN
# 1626       76          2   GT  Lockie Ferguson                 10        NaN
# 1627       76          2   GT       Yash Dayal                 11        NaN
#
#      OutDesc  Runs  Balls  DotBalls  Ones  Twos  Threes  Fours  Sixes  \
# 1623     NaN     0      0         0     0     0       0      0      0
# 1624     NaN     0      0         0     0     0       0      0      0
# 1625     NaN     0      0         0     0     0       0      0      0
# 1626     NaN     0      0         0     0     0       0      0      0
# 1627     NaN     0      0         0     0     0       0      0      0
#
#      StrikeRate  WicketNo  AgainstFast  AgainstSpin
# ...

# %%
bat_df.describe(include=[int])
# Out:
#            MatchID    InningsNo  MatchPlayingOrder         Runs        Balls  \
# count  1628.000000  1628.000000        1628.000000  1628.000000  1628.000000
# mean     37.608108     1.500000           6.000000    14.159705    10.571253
# std      21.547791     0.500154           3.163249    20.275401    13.142609
# min       1.000000     1.000000           1.000000     0.000000     0.000000
# 25%      19.000000     1.000000           3.000000     0.000000     0.000000
# 50%      37.500000     1.500000           6.000000     5.000000     6.000000
# 75%      56.000000     2.000000           9.000000    22.000000    16.000000
# max      76.000000     2.000000          11.000000   140.000000    70.000000
#
#           DotBalls         Ones         Twos       Threes        Fours  \
# count  1628.000000  1628.000000  1628.000000  1628.000000  1628.000000
# mean      4.093980     3.921376     0.627150     0.035627     1.238943
# ...

# %%
bat_df.describe().T
# Out:
#                     count       mean        std  min   25%   50%   75%    max
# MatchID            1628.0  37.608108  21.547791  1.0  19.0  37.5  56.0   76.0
# InningsNo          1628.0   1.500000   0.500154  1.0   1.0   1.5   2.0    2.0
# MatchPlayingOrder  1628.0   6.000000   3.163249  1.0   3.0   6.0   9.0   11.0
# Runs               1628.0  14.159705  20.275401  0.0   0.0   5.0  22.0  140.0
# Balls              1628.0  10.571253  13.142609  0.0   0.0   6.0  16.0   70.0
# DotBalls           1628.0   4.093980   4.778989  0.0   0.0   2.0   7.0   28.0
# Ones               1628.0   3.921376   5.697342  0.0   0.0   1.0   6.0   32.0
# Twos               1628.0   0.627150   1.153994  0.0   0.0   0.0   1.0   10.0
# Threes             1628.0   0.035627   0.201307  0.0   0.0   0.0   0.0    2.0
# Fours              1628.0   1.238943   2.058166  0.0   0.0   0.0   2.0   13.0
# Sixes              1628.0   0.652334   1.272667  0.0   0.0   0.0   1.0   10.0
# ...

# %%
bat_df.shape # Get the number of rows and columns
# Out:
# (1628, 19)

# %%
bat_df.iloc[814]
# Out:
# MatchID                                              38
# InningsNo                                             1
# Team                                               PBSK
# PlayerName                               Mayank Agarwal
# MatchPlayingOrder                                     1
# BowlerName                           Maheesh Theekshana
# OutDesc              c Shivam Dube b Maheesh Theekshana
# Runs                                                 18
# Balls                                                21
# DotBalls                                             10
# Ones                                                  8
# Twos                                                  1
# Threes                                                0
# Fours                                                 2
# Sixes                                                 0
# StrikeRate                                        85.71
# WicketNo                                            2.0
# ...

# %%
bat_df.columns #gives the column names
# Out:
# Index(['MatchID', 'InningsNo', 'Team', 'PlayerName', 'MatchPlayingOrder',
#        'BowlerName', 'OutDesc', 'Runs', 'Balls', 'DotBalls', 'Ones', 'Twos',
#        'Threes', 'Fours', 'Sixes', 'StrikeRate', 'WicketNo', 'AgainstFast',
#        'AgainstSpin'],
#       dtype='object')

# %%
bat_df.info() #gives the information of the data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1628 entries, 0 to 1627
# Data columns (total 19 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   MatchID            1628 non-null   int64
#  1   InningsNo          1628 non-null   int64
#  2   Team               1628 non-null   object
#  3   PlayerName         1628 non-null   object
#  4   MatchPlayingOrder  1628 non-null   int64
#  5   BowlerName         912 non-null    object
#  6   OutDesc            1176 non-null   object
#  7   Runs               1628 non-null   int64
#  8   Balls              1628 non-null   int64
#  9   DotBalls           1628 non-null   int64
#  10  Ones               1628 non-null   int64
#  11  Twos               1628 non-null   int64
#  12  Threes             1628 non-null   int64
#  13  Fours              1628 non-null   int64
#  14  Sixes              1628 non-null   int64
#  15  StrikeRate         1628 non-null   object
# ...

# %% [markdown]
# The total number of rows in the DataFrame.
#
# The number of non-null values in each column, which tells you how complete your data is.
#
# The data type of each column (e.g., integer, float, object/string, datetime, etc.).
#
# The memory usage of the DataFrame, which can be helpful to assess the memory footprint of your data.

# %%
bat_df['PlayerName'] #gives the column data
# Out:
# 0       Ruturaj  Gaikwad
# 1           Devon Conway
# 2          Robin Uthappa
# 3          Ambati Rayudu
# 4        Ravindra Jadeja
#               ...
# 1623         Rashid Khan
# 1624         Sai Kishore
# 1625      Mohammad Shami
# 1626     Lockie Ferguson
# 1627          Yash Dayal
# Name: PlayerName, Length: 1628, dtype: object

# %%
bat_df['PlayerName'].head() #gives the column data
# Out:
# 0    Ruturaj  Gaikwad
# 1        Devon Conway
# 2       Robin Uthappa
# 3       Ambati Rayudu
# 4     Ravindra Jadeja
# Name: PlayerName, dtype: object

# %% [markdown]
# ### The unique values of players in the data

# %% [markdown]
# ### How Many Total Sixes hitted by each Team

# %%
sixes_df = bat_df[['Team', 'Sixes']].groupby('Team').sum() #grouping the data
sixes_df
# Out:
#       Sixes
# Team
# CSK     103
# DC      106
# GT       79
# KKR     113
# LSG     115
# MI      100
# PBSK    110
# RCB     102
# RR      137
# SRH      97

# %%
player=bat_df[bat_df['PlayerName']=='MS Dhoni']

player_df=player[['Runs','Balls','Fours','Sixes','DotBalls','AgainstFast','AgainstSpin','PlayerName','StrikeRate']].groupby('PlayerName').sum()

player_df
# Out:
#             Runs  Balls  Fours  Sixes  DotBalls  AgainstFast  AgainstSpin  \
# PlayerName
# MS Dhoni     232    188     21     10        82          123           63
#
#                                                    StrikeRate
# PlayerName
# MS Dhoni    131.58266.6782.1450.00--215.38150.00114.2966.6...

# %%
top_Batsman = bat_df[["Runs","Balls","PlayerName","Fours","Sixes","StrikeRate","DotBalls"]].groupby("PlayerName").sum().sort_values("Runs",ascending=False).head(1)
top_Batsman
# Out:
#              Runs  Balls  Fours  Sixes  \
# PlayerName
# Jos Buttler   863    579     83     45
#
#                                                     StrikeRate  DotBalls
# PlayerName
# Jos Buttler  125.00147.06148.94118.18225.00168.85178.4688.8...       230

# %%
df2 = bat_df.copy()
df2.loc[2:5,'Team'] = None
df2.head(7)
# Out:
#    MatchID  InningsNo  Team        PlayerName  MatchPlayingOrder  \
# 0        1          1   CSK  Ruturaj  Gaikwad                  1
# 1        1          1   CSK      Devon Conway                  2
# 2        1          1  None     Robin Uthappa                  3
# 3        1          1  None     Ambati Rayudu                  4
# 4        1          1  None   Ravindra Jadeja                  5
# 5        1          1  None       Shivam Dube                  7
# 6        1          1   CSK          MS Dhoni                  6
#
#             BowlerName                                   OutDesc  Runs  Balls  \
# 0          Umesh Yadav               c Nitish Rana b Umesh Yadav     0      4
# 1          Umesh Yadav              c Shreyas Iyer b Umesh Yadav     3      8
# 2  Varun Chakaravarthy  st Sheldon Jackson b Varun Chakaravarthy    28     21
# 3         Sunil Narine                    run out (Shreyas Iyer)    15     17
# ...

# %%
df2.isnull().sum()
# Out:
# MatchID                0
# InningsNo              0
# Team                   4
# PlayerName             0
# MatchPlayingOrder      0
# BowlerName           716
# OutDesc              452
# Runs                   0
# Balls                  0
# DotBalls               0
# Ones                   0
# Twos                   0
# Threes                 0
# Fours                  0
# Sixes                  0
# StrikeRate             0
# WicketNo             717
# AgainstFast            0
# AgainstSpin            0
# dtype: int64

# %%
df2.isnull().sum().sum()
# Out:
# 1889

# %%
bat_df[bat_df.Runs == 100]
# Out:
#      MatchID  InningsNo Team   PlayerName  MatchPlayingOrder      BowlerName  \
# 176        9          1   RR  Jos Buttler                  1  Jasprit Bumrah
#
#               OutDesc  Runs  Balls  DotBalls  Ones  Twos  Threes  Fours  \
# 176  b Jasprit Bumrah   100     68        28    22     2       0     11
#
#      Sixes StrikeRate  WicketNo  AgainstFast  AgainstSpin
# 176      5     147.06      10.0           57           11

# %%
bat_df.plot.line(subplots=True)
# Out:
# array([<Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >,
#        <Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >,
#        <Axes: >, <Axes: >], dtype=object)
